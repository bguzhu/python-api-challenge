# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
#Specify necessary dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#Get unique weather api key from the api_keys python file
from api_keys import weather_api_key

# Import citipy after pip install to find out longitude and latitude for the cities
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for lat and lon data
lat_lngs = []

# Empty list for all the cities
cities = []

# Range of values for longitude and latitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create random longitude and latitude
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#For every latitude and longitude in the list
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #for each city, add it to the cities list
    if city not in cities:
        cities.append(city)

#print the total number of cities
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %%
cities
# Out:
# ['yuni',
#  'port-aux-francais',
#  'adamstown',
#  'santana',
#  'tiksi',
#  'sanming',
#  'port mathurin',
#  'hermanus',
#  'minas de marcona',
#  'georgetown',
#  'taiohae',
#  'waitangi',
#  'arraial do cabo',
#  'ushuaia',
#  'bethel',
#  'mejit',
#  'urangan',
#  'port alfred',
#  'am djarass',
#  'longyearbyen',
#  'bilibino',
#  'namtsy',
#  'vila do maio',
#  'aioun',
#  'gordonvale',
#  'hamilton',
#  'hailin',
#  'katsuura',
#  'kyzyl-mazhalyk',
#  'iqaluit',
#  'usinsk',
#  'hadibu',
#  'jamestown',
#  'howrah',
#  'callao',
#  'recreo',
#  'whitehorse',
#  'juneau',
#  'tazovsky',
#  'nogliki',
#  'blackmans bay',
#  'mo i rana',
#  'invercargill',
#  'broken hill',
#  'porto novo',
#  'grytviken',
#  'albany',
#  'hawaiian paradise park',
#  'wailua homesteads',
#  'misratah',
#  'west island',
#  'edinburgh of the seven seas',
#  'anadyr',
#  'vingt cinq',
#  'port macquarie',
#  'petropavlovsk-kamchatsky',
#  'utrik',
#  'usogorsk',
#  'puerto san jose',
#  'sehore',
#  'ancud',
#  'bandar lampung',
#  'itambe',
#  "'ohonua",
#  'nadi',
#  'urzhar',
#  'hyrum',
#  'nha trang',
#  'visby',
#  'nemuro',
#  'palmeiras de goias',
#  'yellowknife',
#  'lorengau',
#  'puerto ayora',
#  'enewetak',
#  'atwater',
#  'pacific grove',
#  'avarua',
#  'port blair',
#  'papatowai',
#  'aquin',
#  'tateyama',
#  'schramberg',
#  'qamdo',
#  'port-vila',
#  'east london',
#  'polavaram',
#  'margaret river',
#  'jeddah',
#  'arroyo',
#  'xudat',
#  'luba',
#  'colonia',
#  'ponta delgada',
#  'bath',
#  'dabou',
#  'ibipora',
#  'orchard homes',
#  'puerto natales',
#  'oranjemund',
#  'ust-nera',
#  'bluefields',
#  'manaure',
#  'nikolayevsk-on-amure',
#  'hoxtolgay',
#  'hasaki',
#  'la passe',
#  'keflavik',
#  'kargil',
#  'tura',
#  'port elizabeth',
#  'rundu',
#  'naha',
#  'lethem',
#  'iquique',
#  'nova sintra',
#  "al 'alamayn",
#  'vorgashor',
#  'novyye lapsary',
#  'chonchi',
#  'kamina',
#  'coquimbo',
#  'soe',
#  'tolanaro',
#  'olonkinbyen',
#  'manokwari',
#  'cabo san lucas',
#  'wichian buri',
#  'great falls',
#  'baluntaicun',
#  'chilecito',
#  'afaahiti',
#  'dauphin',
#  'uzgen',
#  'labrador city',
#  'lowell',
#  'ribeira grande',
#  'fuglafjordur',
#  'isafjordur',
#  'solapur',
#  'zaozersk',
#  'kani keli',
#  'saint-georges',
#  'yinchuan',
#  'taizhou',
#  'stanley',
#  'teruel',
#  'blagoveshchensk',
#  'saipan',
#  'margate',
#  'laboulaye',
#  'tual',
#  'san patricio',
#  'kroya',
#  'al bardiyah',
#  'alofi',
#  'nyrob',
#  'touros',
#  'williams lake',
#  'richlands',
#  'buritis',
#  'nagqu',
#  'rukban',
#  'puerto san carlos',
#  'san sebastian del sur',
#  'qaqortoq',
#  'karratha',
#  'kerikeri',
#  'dudinka',
#  'veshenskaya',
#  'gwadar',
#  'khandyga',
#  'nacala',
#  'sinabang',
#  'kruisfontein',
#  'atafu village',
#  'santa ana',
#  'dubovskoye',
#  'al kharijah',
#  'carnarvon',
#  'abashiri',
#  'la palma',
#  'sisimiut',
#  'thakhek',
#  'lebu',
#  'mandalgovi',
#  'ras gharib',
#  'bhavnagar',
#  'tomatlan',
#  'udachny',
#  'souillac',
#  'vernon',
#  'cadale',
#  'masterton',
#  'tottori',
#  'el calafate',
#  'mugardos',
#  'lihue',
#  'new brighton',
#  'astrakhan',
#  'caspe',
#  'grand falls-windsor',
#  'kayyerkan',
#  'cole harbour',
#  'luanda',
#  'trincomalee',
#  'shymkent',
#  'sandnessjoen',
#  'northam',
#  'hammerfest',
#  'llallagua',
#  'susuman',
#  'mallawi',
#  'upington',
#  'guerrero negro',
#  'pinckneyville',
#  'ilulissat',
#  'cidreira',
#  'talnakh',
#  'richards bay',
#  'saudarkrokur',
#  'weno',
#  'palmer',
#  'mittenwald',
#  'college',
#  'fort bragg',
#  'north bend',
#  "vrangel'",
#  'anatuya',
#  'sanford',
#  'dingwall',
#  'jayapura',
#  'gaigeturi',
#  'alaghsas',
#  'kone',
#  'mount pearl',
#  'remire-montjoly',
#  'jaciara',
#  'cobija',
#  'urucara',
#  'korla',
#  'alotau',
#  'pahrump',
#  'urucui',
#  'namibe',
#  'muskegon',
#  'moquegua',
#  'palora',
#  'aykhal',
#  'rio grande',
#  'ouallam',
#  'rendon',
#  'pakse',
#  'axim',
#  'maumere',
#  'taltal',
#  'ijebu-ode',
#  'vilyuysk',
#  'bairnsdale',
#  'cayambe',
#  'lembar',
#  'melfort',
#  'koulikoro',
#  'siwa oasis',
#  'si bun rueang',
#  'dalbandin',
#  'vyksa',
#  'tazacorte',
#  'port shepstone',
#  'bredasdorp',
#  'luderitz',
#  'klyuchi',
#  'castillos',
#  'sarandi del yi',
#  'cateel',
#  'teguise',
#  'severo-yeniseyskiy',
#  'buncrana',
#  'ladyzhyn',
#  'drogheda',
#  'tongouson',
#  'sambava',
#  'ghat',
#  'christchurch',
#  'zouerate',
#  'sungai besar',
#  'vorkuta',
#  'muynoq',
#  'inderbor',
#  'karamay',
#  'lazaro cardenas',
#  'domna',
#  'portland',
#  'tvoroyri',
#  'goure',
#  'rabaul',
#  'piti village',
#  'maturin',
#  'fale old settlement',
#  'bridgewater',
#  'sao joao da barra',
#  'danilov',
#  'berdigestyakh',
#  'basyayla',
#  'kodiak',
#  'mermoz boabab',
#  'crozon',
#  'sitka',
#  'fort st. john',
#  'sodankyla',
#  'punta arenas',
#  'mushie',
#  'kinkala',
#  'mili',
#  'sinjai',
#  'borogontsy',
#  'ebaye',
#  'san antonio de pale',
#  'ketchikan',
#  'sarangani',
#  'ouellah',
#  'miracema do tocantins',
#  'hithadhoo',
#  'westport',
#  'matay',
#  'luganville',
#  "'ain deheb",
#  'san sebastian de la gomera',
#  'mary',
#  'tsiombe',
#  "ha'il",
#  'harstad',
#  'wodonga',
#  'duba',
#  'copiapo',
#  'crane',
#  'egilsstadir',
#  'thompson',
#  'mahina',
#  'morehead city',
#  'port lincoln',
#  'mahabad',
#  'vila franca do campo',
#  'tralee',
#  'koungou',
#  'karasu mahallesi',
#  'guayaramerin',
#  'cargados carajos',
#  'constitucion',
#  'erdenet',
#  'crucecita',
#  'dzerzhinskoye',
#  'maputo',
#  'sao gabriel da cachoeira',
#  'fortuna',
#  'lianran',
#  'chibougamau',
#  'illizi',
#  'nizhneudinsk',
#  "port saint john's",
#  'vadso',
#  'krasnyy kut',
#  'luau',
#  'puebloviejo',
#  'arno',
#  'lompoc',
#  'bocas del toro',
#  'san andres',
#  'rapid city',
#  'quellon',
#  'withernsea',
#  'holualoa',
#  'fuerte olimpo',
#  'aquidauana',
#  'los andes',
#  'isangel',
#  'kulia village',
#  'nishinoomote',
#  "nar'yan-mar",
#  'wingham',
#  'colby',
#  'alliance',
#  'kinna',
#  'porvoo',
#  'sao tome',
#  'mormugao',
#  'devinuwara',
#  'strezhevoy',
#  'arzua',
#  'ginir',
#  'kefamenanu',
#  'vilyuchinsk',
#  'yermentau',
#  'grand rapids',
#  'baiti',
#  'chiplun',
#  'justo daract',
#  'sainte-anne-des-monts',
#  'qurayyat',
#  'ammon',
#  'malango',
#  'bikenibeu village',
#  'ameca',
#  'machico',
#  'palwal',
#  'port hedland',
#  'hotan',
#  'taroa',
#  'kingston',
#  'nema',
#  'bamboo flat',
#  'puerto aysen',
#  'smithers',
#  'vieste',
#  'spittal an der drau',
#  'at-bashi',
#  'impfondo',
#  'goondiwindi',
#  'sumter',
#  'abra pampa',
#  'constantia',
#  'villa gesell',
#  "kapa'a",
#  'pangody',
#  'piui',
#  'beyneu',
#  'tubarjal',
#  'carutapera',
#  'newman',
#  'markala',
#  'alice springs',
#  'singaparna',
#  'i-n-salah',
#  'tanjung pandan',
#  'naze',
#  'kavadarci',
#  'shakawe',
#  'geraldton',
#  'lobujya',
#  'samarinda',
#  'zhuanghe',
#  'larroque',
#  'coronel suarez',
#  'iskateley',
#  'kidal',
#  'tekkali',
#  'gaiman',
#  'ninghai',
#  'kovalam',
#  'kindu',
#  'mount isa',
#  'yamada',
#  'chapaev',
#  'papao',
#  'veroia',
#  'ontario',
#  'kapuskasing',
#  'malvan',
#  'kabalo',
#  'lapa',
#  'choibalsan',
#  'flying fish cove',
#  'lospalos',
#  'fort-shevchenko',
#  'chernyshevskiy',
#  'gaspe',
#  'badger',
#  'saldanha',
#  'happy valley-goose bay',
#  'hovd',
#  'ain beni mathar',
#  'praia da vitoria',
#  'sao joao do paraiso',
#  'santander',
#  'sur',
#  'trairi',
#  'goundam',
#  'hilo',
#  'midvagur',
#  'irymple',
#  'taro',
#  'pathein',
#  'emerald',
#  'amstetten',
#  'mazagao',
#  'tabas',
#  'whangarei',
#  'kuala belait',
#  'belozersk',
#  'kirakira',
#  'timaru',
#  'coney island',
#  'podgornoye',
#  'brokopondo',
#  'cardenas',
#  'suhbaatar',
#  'creston',
#  'carauari',
#  'picos',
#  'tapes',
#  'petrolina',
#  'nyaunglebin',
#  'bonthe',
#  'uturoa',
#  'whakatane',
#  'polyarnyy',
#  'inongo',
#  'dahab',
#  'vredendal',
#  "gur'yevsk",
#  'bartolome maso',
#  'ayaguz',
#  'lycksele',
#  'puerto baquerizo moreno',
#  'seogwipo',
#  'maceio',
#  'besuki',
#  'grajau',
#  'mar del plata',
#  "yelan'-koleno",
#  'safaga',
#  'kayangel',
#  'gazojak',
#  'pyay',
#  'darwin',
#  'new norfolk',
#  'zunyi',
#  'roma',
#  'itoman',
#  'mount airy',
#  'calvi',
#  'broome',
#  'ta`u',
#  'north bay',
#  'raciborz',
#  'kermanshah',
#  'canico',
#  'mikhaylovka',
#  'dumbea',
#  'dunedin',
#  'la ronge',
#  'krasnyye baki',
#  'louis trichardt',
#  'djambala',
#  'sinjar',
#  'antsiranana',
#  'tres arroyos',
#  'ordynskoye',
#  "hayma'",
#  'aasiaat',
#  'kathmandu',
#  'narathiwat',
#  'roxas',
#  'humberto de campos',
#  'benjamin constant',
#  'myeik',
#  'atlantis',
#  'trnava',
#  'lerwick',
#  'ulsteinvik',
#  'celestun',
#  'mubende',
#  'monte alegre',
#  'kavaratti',
#  'cordeiropolis',
#  'elliot lake',
#  'nabire',
#  'chegdomyn',
#  'tabou',
#  'saint-philippe',
#  'lingig',
#  'dalnegorsk',
#  'pikalevo',
#  'rongelap',
#  'nuuk',
#  'alenquer',
#  'tromso',
#  'lugu',
#  'campobello di mazara',
#  'guarapuava',
#  'la junta',
#  'sredets',
#  'ciudad bolivar',
#  'maun',
#  'imeni morozova',
#  'haiku-pauwela',
#  'santa rosalia',
#  'aleksandrovsk',
#  'bodo',
#  'madinat sittah uktubar',
#  'pombas',
#  'bakchar',
#  'fuvahmulah',
#  'nangomba',
#  'ungsang-nodongjagu',
#  'ambon',
#  'tangalle',
#  'daru',
#  'calama',
#  'sawakin',
#  "ust'-kut",
#  'belmonte',
#  'buala',
#  'guilmaro',
#  'piatykhatky']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=a4b719b11af797ca58c5942b718aabdc&q=san francisco

# %%
#Define base url with unique weather api key
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

#Create an empty list to get the weather data for each city
city_data = []

#Print to tell the user that data is being gathered
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters for record and set
record_count = 1
set_count = 1

#Loop through all the cities in city_data to get weather data
for i, city in enumerate(cities):
        
    #Group cities in groups of 50 each
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    #Create endpoint URL for each city
    city_url = f"{url}&q={city}"
    
    #Keep track the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    #Increment the record count by 1
    record_count += 1

    #Run an API request for each of the cities
    try:
        #Get the request and convert to json to get the raw data
        city_weather = requests.get(city_url).json()

        #Take the latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        #Append the previous values into the city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
#Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yuni
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | santana
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | sanming
# Processing Record 7 of Set 1 | port mathurin
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | minas de marcona
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | mejit
# Processing Record 17 of Set 1 | urangan
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | bilibino
# Processing Record 22 of Set 1 | namtsy
# Processing Record 23 of Set 1 | vila do maio
# Processing Record 24 of Set 1 | aioun
# Processing Record 25 of Set 1 | gordonvale
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | hailin
# Processing Record 28 of Set 1 | katsuura
# Processing Record 29 of Set 1 | kyzyl-mazhalyk
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | usinsk
# Processing Record 32 of Set 1 | hadibu
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | howrah
# Processing Record 35 of Set 1 | callao
# Processing Record 36 of Set 1 | recreo
# Processing Record 37 of Set 1 | whitehorse
# Processing Record 38 of Set 1 | juneau
# Processing Record 39 of Set 1 | tazovsky
# Processing Record 40 of Set 1 | nogliki
# Processing Record 41 of Set 1 | blackmans bay
# Processing Record 42 of Set 1 | mo i rana
# Processing Record 43 of Set 1 | invercargill
# Processing Record 44 of Set 1 | broken hill
# Processing Record 45 of Set 1 | porto novo
# Processing Record 46 of Set 1 | grytviken
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | hawaiian paradise park
# Processing Record 49 of Set 1 | wailua homesteads
# Processing Record 50 of Set 1 | misratah
# Processing Record 0 of Set 2 | west island
# Processing Record 1 of Set 2 | edinburgh of the seven seas
# Processing Record 2 of Set 2 | anadyr
# Processing Record 3 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 4 of Set 2 | port macquarie
# Processing Record 5 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 2 | utrik
# Processing Record 7 of Set 2 | usogorsk
# Processing Record 8 of Set 2 | puerto san jose
# Processing Record 9 of Set 2 | sehore
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | bandar lampung
# Processing Record 12 of Set 2 | itambe
# Processing Record 13 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 2 | nadi
# Processing Record 15 of Set 2 | urzhar
# Processing Record 16 of Set 2 | hyrum
# Processing Record 17 of Set 2 | nha trang
# Processing Record 18 of Set 2 | visby
# Processing Record 19 of Set 2 | nemuro
# Processing Record 20 of Set 2 | palmeiras de goias
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | lorengau
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | enewetak
# Processing Record 25 of Set 2 | atwater
# Processing Record 26 of Set 2 | pacific grove
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | papatowai
# Processing Record 30 of Set 2 | aquin
# Processing Record 31 of Set 2 | tateyama
# Processing Record 32 of Set 2 | schramberg
# Processing Record 33 of Set 2 | qamdo
# Processing Record 34 of Set 2 | port-vila
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | polavaram
# City not found. Skipping...
# Processing Record 37 of Set 2 | margaret river
# Processing Record 38 of Set 2 | jeddah
# Processing Record 39 of Set 2 | arroyo
# Processing Record 40 of Set 2 | xudat
# Processing Record 41 of Set 2 | luba
# Processing Record 42 of Set 2 | colonia
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | bath
# Processing Record 45 of Set 2 | dabou
# Processing Record 46 of Set 2 | ibipora
# Processing Record 47 of Set 2 | orchard homes
# Processing Record 48 of Set 2 | puerto natales
# Processing Record 49 of Set 2 | oranjemund
# Processing Record 0 of Set 3 | ust-nera
# Processing Record 1 of Set 3 | bluefields
# Processing Record 2 of Set 3 | manaure
# Processing Record 3 of Set 3 | nikolayevsk-on-amure
# Processing Record 4 of Set 3 | hoxtolgay
# City not found. Skipping...
# Processing Record 5 of Set 3 | hasaki
# Processing Record 6 of Set 3 | la passe
# Processing Record 7 of Set 3 | keflavik
# Processing Record 8 of Set 3 | kargil
# Processing Record 9 of Set 3 | tura
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | rundu
# Processing Record 12 of Set 3 | naha
# Processing Record 13 of Set 3 | lethem
# Processing Record 14 of Set 3 | iquique
# Processing Record 15 of Set 3 | nova sintra
# Processing Record 16 of Set 3 | al 'alamayn
# City not found. Skipping...
# Processing Record 17 of Set 3 | vorgashor
# Processing Record 18 of Set 3 | novyye lapsary
# Processing Record 19 of Set 3 | chonchi
# Processing Record 20 of Set 3 | kamina
# Processing Record 21 of Set 3 | coquimbo
# Processing Record 22 of Set 3 | soe
# Processing Record 23 of Set 3 | tolanaro
# Processing Record 24 of Set 3 | olonkinbyen
# Processing Record 25 of Set 3 | manokwari
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | wichian buri
# Processing Record 28 of Set 3 | great falls
# Processing Record 29 of Set 3 | baluntaicun
# City not found. Skipping...
# Processing Record 30 of Set 3 | chilecito
# Processing Record 31 of Set 3 | afaahiti
# Processing Record 32 of Set 3 | dauphin
# Processing Record 33 of Set 3 | uzgen
# Processing Record 34 of Set 3 | labrador city
# Processing Record 35 of Set 3 | lowell
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | fuglafjordur
# Processing Record 38 of Set 3 | isafjordur
# Processing Record 39 of Set 3 | solapur
# Processing Record 40 of Set 3 | zaozersk
# Processing Record 41 of Set 3 | kani keli
# Processing Record 42 of Set 3 | saint-georges
# Processing Record 43 of Set 3 | yinchuan
# Processing Record 44 of Set 3 | taizhou
# Processing Record 45 of Set 3 | stanley
# Processing Record 46 of Set 3 | teruel
# Processing Record 47 of Set 3 | blagoveshchensk
# Processing Record 48 of Set 3 | saipan
# Processing Record 49 of Set 3 | margate
# Processing Record 0 of Set 4 | laboulaye
# Processing Record 1 of Set 4 | tual
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | kroya
# Processing Record 4 of Set 4 | al bardiyah
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | nyrob
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | williams lake
# Processing Record 9 of Set 4 | richlands
# Processing Record 10 of Set 4 | buritis
# Processing Record 11 of Set 4 | nagqu
# Processing Record 12 of Set 4 | rukban
# City not found. Skipping...
# Processing Record 13 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 4 | san sebastian del sur
# City not found. Skipping...
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | kerikeri
# Processing Record 18 of Set 4 | dudinka
# Processing Record 19 of Set 4 | veshenskaya
# Processing Record 20 of Set 4 | gwadar
# Processing Record 21 of Set 4 | khandyga
# Processing Record 22 of Set 4 | nacala
# Processing Record 23 of Set 4 | sinabang
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | atafu village
# Processing Record 26 of Set 4 | santa ana
# Processing Record 27 of Set 4 | dubovskoye
# Processing Record 28 of Set 4 | al kharijah
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | abashiri
# Processing Record 31 of Set 4 | la palma
# Processing Record 32 of Set 4 | sisimiut
# Processing Record 33 of Set 4 | thakhek
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | mandalgovi
# Processing Record 36 of Set 4 | ras gharib
# City not found. Skipping...
# Processing Record 37 of Set 4 | bhavnagar
# Processing Record 38 of Set 4 | tomatlan
# Processing Record 39 of Set 4 | udachny
# Processing Record 40 of Set 4 | souillac
# Processing Record 41 of Set 4 | vernon
# Processing Record 42 of Set 4 | cadale
# Processing Record 43 of Set 4 | masterton
# Processing Record 44 of Set 4 | tottori
# Processing Record 45 of Set 4 | el calafate
# Processing Record 46 of Set 4 | mugardos
# Processing Record 47 of Set 4 | lihue
# Processing Record 48 of Set 4 | new brighton
# Processing Record 49 of Set 4 | astrakhan
# Processing Record 0 of Set 5 | caspe
# Processing Record 1 of Set 5 | grand falls-windsor
# Processing Record 2 of Set 5 | kayyerkan
# Processing Record 3 of Set 5 | cole harbour
# Processing Record 4 of Set 5 | luanda
# Processing Record 5 of Set 5 | trincomalee
# Processing Record 6 of Set 5 | shymkent
# Processing Record 7 of Set 5 | sandnessjoen
# Processing Record 8 of Set 5 | northam
# Processing Record 9 of Set 5 | hammerfest
# Processing Record 10 of Set 5 | llallagua
# Processing Record 11 of Set 5 | susuman
# Processing Record 12 of Set 5 | mallawi
# Processing Record 13 of Set 5 | upington
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | pinckneyville
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | talnakh
# Processing Record 19 of Set 5 | richards bay
# Processing Record 20 of Set 5 | saudarkrokur
# Processing Record 21 of Set 5 | weno
# Processing Record 22 of Set 5 | palmer
# Processing Record 23 of Set 5 | mittenwald
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | fort bragg
# Processing Record 26 of Set 5 | north bend
# Processing Record 27 of Set 5 | vrangel'
# Processing Record 28 of Set 5 | anatuya
# Processing Record 29 of Set 5 | sanford
# Processing Record 30 of Set 5 | dingwall
# Processing Record 31 of Set 5 | jayapura
# Processing Record 32 of Set 5 | gaigeturi
# Processing Record 33 of Set 5 | alaghsas
# Processing Record 34 of Set 5 | kone
# Processing Record 35 of Set 5 | mount pearl
# Processing Record 36 of Set 5 | remire-montjoly
# Processing Record 37 of Set 5 | jaciara
# Processing Record 38 of Set 5 | cobija
# Processing Record 39 of Set 5 | urucara
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 5 | pahrump
# Processing Record 43 of Set 5 | urucui
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | muskegon
# Processing Record 46 of Set 5 | moquegua
# Processing Record 47 of Set 5 | palora
# Processing Record 48 of Set 5 | aykhal
# Processing Record 49 of Set 5 | rio grande
# Processing Record 0 of Set 6 | ouallam
# Processing Record 1 of Set 6 | rendon
# Processing Record 2 of Set 6 | pakse
# Processing Record 3 of Set 6 | axim
# Processing Record 4 of Set 6 | maumere
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | ijebu-ode
# Processing Record 7 of Set 6 | vilyuysk
# Processing Record 8 of Set 6 | bairnsdale
# Processing Record 9 of Set 6 | cayambe
# Processing Record 10 of Set 6 | lembar
# City not found. Skipping...
# Processing Record 11 of Set 6 | melfort
# Processing Record 12 of Set 6 | koulikoro
# Processing Record 13 of Set 6 | siwa oasis
# Processing Record 14 of Set 6 | si bun rueang
# Processing Record 15 of Set 6 | dalbandin
# Processing Record 16 of Set 6 | vyksa
# Processing Record 17 of Set 6 | tazacorte
# Processing Record 18 of Set 6 | port shepstone
# Processing Record 19 of Set 6 | bredasdorp
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | klyuchi
# Processing Record 22 of Set 6 | castillos
# Processing Record 23 of Set 6 | sarandi del yi
# Processing Record 24 of Set 6 | cateel
# Processing Record 25 of Set 6 | teguise
# Processing Record 26 of Set 6 | severo-yeniseyskiy
# Processing Record 27 of Set 6 | buncrana
# Processing Record 28 of Set 6 | ladyzhyn
# Processing Record 29 of Set 6 | drogheda
# Processing Record 30 of Set 6 | tongouson
# Processing Record 31 of Set 6 | sambava
# Processing Record 32 of Set 6 | ghat
# Processing Record 33 of Set 6 | christchurch
# Processing Record 34 of Set 6 | zouerate
# Processing Record 35 of Set 6 | sungai besar
# Processing Record 36 of Set 6 | vorkuta
# Processing Record 37 of Set 6 | muynoq
# Processing Record 38 of Set 6 | inderbor
# Processing Record 39 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 40 of Set 6 | lazaro cardenas
# Processing Record 41 of Set 6 | domna
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | tvoroyri
# Processing Record 44 of Set 6 | goure
# Processing Record 45 of Set 6 | rabaul
# Processing Record 46 of Set 6 | piti village
# Processing Record 47 of Set 6 | maturin
# Processing Record 48 of Set 6 | fale old settlement
# Processing Record 49 of Set 6 | bridgewater
# Processing Record 0 of Set 7 | sao joao da barra
# Processing Record 1 of Set 7 | danilov
# Processing Record 2 of Set 7 | berdigestyakh
# Processing Record 3 of Set 7 | basyayla
# Processing Record 4 of Set 7 | kodiak
# Processing Record 5 of Set 7 | mermoz boabab
# Processing Record 6 of Set 7 | crozon
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | fort st. john
# Processing Record 9 of Set 7 | sodankyla
# Processing Record 10 of Set 7 | punta arenas
# Processing Record 11 of Set 7 | mushie
# Processing Record 12 of Set 7 | kinkala
# Processing Record 13 of Set 7 | mili
# Processing Record 14 of Set 7 | sinjai
# Processing Record 15 of Set 7 | borogontsy
# Processing Record 16 of Set 7 | ebaye
# Processing Record 17 of Set 7 | san antonio de pale
# Processing Record 18 of Set 7 | ketchikan
# Processing Record 19 of Set 7 | sarangani
# Processing Record 20 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 21 of Set 7 | miracema do tocantins
# Processing Record 22 of Set 7 | hithadhoo
# Processing Record 23 of Set 7 | westport
# Processing Record 24 of Set 7 | matay
# Processing Record 25 of Set 7 | luganville
# Processing Record 26 of Set 7 | 'ain deheb
# Processing Record 27 of Set 7 | san sebastian de la gomera
# Processing Record 28 of Set 7 | mary
# Processing Record 29 of Set 7 | tsiombe
# Processing Record 30 of Set 7 | ha'il
# Processing Record 31 of Set 7 | harstad
# Processing Record 32 of Set 7 | wodonga
# Processing Record 33 of Set 7 | duba
# Processing Record 34 of Set 7 | copiapo
# Processing Record 35 of Set 7 | crane
# Processing Record 36 of Set 7 | egilsstadir
# Processing Record 37 of Set 7 | thompson
# Processing Record 38 of Set 7 | mahina
# Processing Record 39 of Set 7 | morehead city
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | mahabad
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 | tralee
# Processing Record 44 of Set 7 | koungou
# Processing Record 45 of Set 7 | karasu mahallesi
# Processing Record 46 of Set 7 | guayaramerin
# Processing Record 47 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 48 of Set 7 | constitucion
# Processing Record 49 of Set 7 | erdenet
# Processing Record 0 of Set 8 | crucecita
# Processing Record 1 of Set 8 | dzerzhinskoye
# Processing Record 2 of Set 8 | maputo
# Processing Record 3 of Set 8 | sao gabriel da cachoeira
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | lianran
# Processing Record 6 of Set 8 | chibougamau
# Processing Record 7 of Set 8 | illizi
# Processing Record 8 of Set 8 | nizhneudinsk
# Processing Record 9 of Set 8 | port saint john's
# Processing Record 10 of Set 8 | vadso
# Processing Record 11 of Set 8 | krasnyy kut
# Processing Record 12 of Set 8 | luau
# Processing Record 13 of Set 8 | puebloviejo
# Processing Record 14 of Set 8 | arno
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | bocas del toro
# Processing Record 17 of Set 8 | san andres
# Processing Record 18 of Set 8 | rapid city
# Processing Record 19 of Set 8 | quellon
# Processing Record 20 of Set 8 | withernsea
# Processing Record 21 of Set 8 | holualoa
# Processing Record 22 of Set 8 | fuerte olimpo
# Processing Record 23 of Set 8 | aquidauana
# Processing Record 24 of Set 8 | los andes
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 27 of Set 8 | nishinoomote
# Processing Record 28 of Set 8 | nar'yan-mar
# Processing Record 29 of Set 8 | wingham
# Processing Record 30 of Set 8 | colby
# Processing Record 31 of Set 8 | alliance
# Processing Record 32 of Set 8 | kinna
# Processing Record 33 of Set 8 | porvoo
# Processing Record 34 of Set 8 | sao tome
# Processing Record 35 of Set 8 | mormugao
# Processing Record 36 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 8 | strezhevoy
# Processing Record 38 of Set 8 | arzua
# Processing Record 39 of Set 8 | ginir
# Processing Record 40 of Set 8 | kefamenanu
# Processing Record 41 of Set 8 | vilyuchinsk
# Processing Record 42 of Set 8 | yermentau
# Processing Record 43 of Set 8 | grand rapids
# Processing Record 44 of Set 8 | baiti
# Processing Record 45 of Set 8 | chiplun
# Processing Record 46 of Set 8 | justo daract
# Processing Record 47 of Set 8 | sainte-anne-des-monts
# Processing Record 48 of Set 8 | qurayyat
# Processing Record 49 of Set 8 | ammon
# Processing Record 0 of Set 9 | malango
# Processing Record 1 of Set 9 | bikenibeu village
# Processing Record 2 of Set 9 | ameca
# Processing Record 3 of Set 9 | machico
# Processing Record 4 of Set 9 | palwal
# Processing Record 5 of Set 9 | port hedland
# Processing Record 6 of Set 9 | hotan
# Processing Record 7 of Set 9 | taroa
# Processing Record 8 of Set 9 | kingston
# Processing Record 9 of Set 9 | nema
# Processing Record 10 of Set 9 | bamboo flat
# Processing Record 11 of Set 9 | puerto aysen
# Processing Record 12 of Set 9 | smithers
# Processing Record 13 of Set 9 | vieste
# Processing Record 14 of Set 9 | spittal an der drau
# Processing Record 15 of Set 9 | at-bashi
# Processing Record 16 of Set 9 | impfondo
# Processing Record 17 of Set 9 | goondiwindi
# Processing Record 18 of Set 9 | sumter
# Processing Record 19 of Set 9 | abra pampa
# Processing Record 20 of Set 9 | constantia
# Processing Record 21 of Set 9 | villa gesell
# Processing Record 22 of Set 9 | kapa'a
# Processing Record 23 of Set 9 | pangody
# Processing Record 24 of Set 9 | piui
# Processing Record 25 of Set 9 | beyneu
# Processing Record 26 of Set 9 | tubarjal
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | newman
# Processing Record 29 of Set 9 | markala
# Processing Record 30 of Set 9 | alice springs
# Processing Record 31 of Set 9 | singaparna
# Processing Record 32 of Set 9 | i-n-salah
# Processing Record 33 of Set 9 | tanjung pandan
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | kavadarci
# Processing Record 36 of Set 9 | shakawe
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | lobujya
# Processing Record 39 of Set 9 | samarinda
# Processing Record 40 of Set 9 | zhuanghe
# Processing Record 41 of Set 9 | larroque
# Processing Record 42 of Set 9 | coronel suarez
# Processing Record 43 of Set 9 | iskateley
# Processing Record 44 of Set 9 | kidal
# Processing Record 45 of Set 9 | tekkali
# Processing Record 46 of Set 9 | gaiman
# Processing Record 47 of Set 9 | ninghai
# Processing Record 48 of Set 9 | kovalam
# Processing Record 49 of Set 9 | kindu
# Processing Record 0 of Set 10 | mount isa
# Processing Record 1 of Set 10 | yamada
# Processing Record 2 of Set 10 | chapaev
# Processing Record 3 of Set 10 | papao
# Processing Record 4 of Set 10 | veroia
# Processing Record 5 of Set 10 | ontario
# Processing Record 6 of Set 10 | kapuskasing
# Processing Record 7 of Set 10 | malvan
# Processing Record 8 of Set 10 | kabalo
# Processing Record 9 of Set 10 | lapa
# Processing Record 10 of Set 10 | choibalsan
# Processing Record 11 of Set 10 | flying fish cove
# Processing Record 12 of Set 10 | lospalos
# Processing Record 13 of Set 10 | fort-shevchenko
# Processing Record 14 of Set 10 | chernyshevskiy
# Processing Record 15 of Set 10 | gaspe
# Processing Record 16 of Set 10 | badger
# Processing Record 17 of Set 10 | saldanha
# Processing Record 18 of Set 10 | happy valley-goose bay
# Processing Record 19 of Set 10 | hovd
# Processing Record 20 of Set 10 | ain beni mathar
# City not found. Skipping...
# Processing Record 21 of Set 10 | praia da vitoria
# Processing Record 22 of Set 10 | sao joao do paraiso
# Processing Record 23 of Set 10 | santander
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | trairi
# Processing Record 26 of Set 10 | goundam
# Processing Record 27 of Set 10 | hilo
# Processing Record 28 of Set 10 | midvagur
# Processing Record 29 of Set 10 | irymple
# Processing Record 30 of Set 10 | taro
# Processing Record 31 of Set 10 | pathein
# Processing Record 32 of Set 10 | emerald
# Processing Record 33 of Set 10 | amstetten
# Processing Record 34 of Set 10 | mazagao
# Processing Record 35 of Set 10 | tabas
# Processing Record 36 of Set 10 | whangarei
# Processing Record 37 of Set 10 | kuala belait
# Processing Record 38 of Set 10 | belozersk
# Processing Record 39 of Set 10 | kirakira
# Processing Record 40 of Set 10 | timaru
# Processing Record 41 of Set 10 | coney island
# Processing Record 42 of Set 10 | podgornoye
# Processing Record 43 of Set 10 | brokopondo
# Processing Record 44 of Set 10 | cardenas
# Processing Record 45 of Set 10 | suhbaatar
# Processing Record 46 of Set 10 | creston
# Processing Record 47 of Set 10 | carauari
# Processing Record 48 of Set 10 | picos
# Processing Record 49 of Set 10 | tapes
# Processing Record 0 of Set 11 | petrolina
# Processing Record 1 of Set 11 | nyaunglebin
# Processing Record 2 of Set 11 | bonthe
# Processing Record 3 of Set 11 | uturoa
# Processing Record 4 of Set 11 | whakatane
# Processing Record 5 of Set 11 | polyarnyy
# Processing Record 6 of Set 11 | inongo
# Processing Record 7 of Set 11 | dahab
# Processing Record 8 of Set 11 | vredendal
# Processing Record 9 of Set 11 | gur'yevsk
# Processing Record 10 of Set 11 | bartolome maso
# City not found. Skipping...
# Processing Record 11 of Set 11 | ayaguz
# City not found. Skipping...
# Processing Record 12 of Set 11 | lycksele
# Processing Record 13 of Set 11 | puerto baquerizo moreno
# Processing Record 14 of Set 11 | seogwipo
# City not found. Skipping...
# Processing Record 15 of Set 11 | maceio
# Processing Record 16 of Set 11 | besuki
# Processing Record 17 of Set 11 | grajau
# Processing Record 18 of Set 11 | mar del plata
# Processing Record 19 of Set 11 | yelan'-koleno
# Processing Record 20 of Set 11 | safaga
# Processing Record 21 of Set 11 | kayangel
# Processing Record 22 of Set 11 | gazojak
# Processing Record 23 of Set 11 | pyay
# Processing Record 24 of Set 11 | darwin
# Processing Record 25 of Set 11 | new norfolk
# Processing Record 26 of Set 11 | zunyi
# Processing Record 27 of Set 11 | roma
# Processing Record 28 of Set 11 | itoman
# Processing Record 29 of Set 11 | mount airy
# Processing Record 30 of Set 11 | calvi
# Processing Record 31 of Set 11 | broome
# Processing Record 32 of Set 11 | ta`u
# Processing Record 33 of Set 11 | north bay
# Processing Record 34 of Set 11 | raciborz
# Processing Record 35 of Set 11 | kermanshah
# Processing Record 36 of Set 11 | canico
# Processing Record 37 of Set 11 | mikhaylovka
# Processing Record 38 of Set 11 | dumbea
# Processing Record 39 of Set 11 | dunedin
# Processing Record 40 of Set 11 | la ronge
# Processing Record 41 of Set 11 | krasnyye baki
# Processing Record 42 of Set 11 | louis trichardt
# Processing Record 43 of Set 11 | djambala
# Processing Record 44 of Set 11 | sinjar
# Processing Record 45 of Set 11 | antsiranana
# Processing Record 46 of Set 11 | tres arroyos
# Processing Record 47 of Set 11 | ordynskoye
# Processing Record 48 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 49 of Set 11 | aasiaat
# Processing Record 0 of Set 12 | kathmandu
# Processing Record 1 of Set 12 | narathiwat
# Processing Record 2 of Set 12 | roxas
# Processing Record 3 of Set 12 | humberto de campos
# Processing Record 4 of Set 12 | benjamin constant
# Processing Record 5 of Set 12 | myeik
# Processing Record 6 of Set 12 | atlantis
# Processing Record 7 of Set 12 | trnava
# Processing Record 8 of Set 12 | lerwick
# Processing Record 9 of Set 12 | ulsteinvik
# Processing Record 10 of Set 12 | celestun
# Processing Record 11 of Set 12 | mubende
# Processing Record 12 of Set 12 | monte alegre
# Processing Record 13 of Set 12 | kavaratti
# Processing Record 14 of Set 12 | cordeiropolis
# Processing Record 15 of Set 12 | elliot lake
# Processing Record 16 of Set 12 | nabire
# Processing Record 17 of Set 12 | chegdomyn
# Processing Record 18 of Set 12 | tabou
# Processing Record 19 of Set 12 | saint-philippe
# Processing Record 20 of Set 12 | lingig
# Processing Record 21 of Set 12 | dalnegorsk
# Processing Record 22 of Set 12 | pikalevo
# Processing Record 23 of Set 12 | rongelap
# Processing Record 24 of Set 12 | nuuk
# Processing Record 25 of Set 12 | alenquer
# Processing Record 26 of Set 12 | tromso
# Processing Record 27 of Set 12 | lugu
# Processing Record 28 of Set 12 | campobello di mazara
# Processing Record 29 of Set 12 | guarapuava
# Processing Record 30 of Set 12 | la junta
# Processing Record 31 of Set 12 | sredets
# Processing Record 32 of Set 12 | ciudad bolivar
# Processing Record 33 of Set 12 | maun
# Processing Record 34 of Set 12 | imeni morozova
# Processing Record 35 of Set 12 | haiku-pauwela
# Processing Record 36 of Set 12 | santa rosalia
# Processing Record 37 of Set 12 | aleksandrovsk
# Processing Record 38 of Set 12 | bodo
# Processing Record 39 of Set 12 | madinat sittah uktubar
# Processing Record 40 of Set 12 | pombas
# Processing Record 41 of Set 12 | bakchar
# Processing Record 42 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 43 of Set 12 | nangomba
# Processing Record 44 of Set 12 | ungsang-nodongjagu
# Processing Record 45 of Set 12 | ambon
# Processing Record 46 of Set 12 | tangalle
# Processing Record 47 of Set 12 | daru
# Processing Record 48 of Set 12 | calama
# Processing Record 49 of Set 12 | sawakin
# Processing Record 0 of Set 13 | ust'-kut
# Processing Record 1 of Set 13 | belmonte
# Processing Record 2 of Set 13 | buala
# Processing Record 3 of Set 13 | guilmaro
# City not found. Skipping...
# Processing Record 4 of Set 13 | piatykhatky
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#Show the count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
#Show the dataframe for the first five rows
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               yuni  13.4192  122.4833     29.59        72          52
# 1  port-aux-francais -49.3500   70.2167      5.49        92          97
# 2          adamstown -25.0660 -130.1015     17.80        91         100
# 3            santana  -0.0583  -51.1817     27.10        89           0
# 4              tiksi  71.6872  128.8694      1.92        71         100
#
#    Wind Speed Country        Date
# 0        1.79      PH  1694841475
# 1       15.61      TF  1694841475
# 2       15.88      PN  1694841476
# 3        4.12      BR  1694841476
# 4        7.79      RU  1694841476

# %%
#Export the city data dataframe to a csv file named cities.csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 2
#       1 #Export the city data dataframe to a csv file named cities.csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
