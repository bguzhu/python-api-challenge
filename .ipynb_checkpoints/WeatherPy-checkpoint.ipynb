# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy

# %%
#Specify necessary dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#Get unique weather api key from the api_keys python file
from api_keys import weather_api_key

# Import citipy after pip install to find out longitude and latitude for the cities
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for lat and lon data
lat_lngs = []

# Empty list for all the cities
cities = []

# Range of values for longitude and latitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create random longitude and latitude
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#For every latitude and longitude in the list
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #for each city, add it to the cities list
    if city not in cities:
        cities.append(city)

#print the total number of cities
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %%
cities
# Out:
# ['hasaki',
#  'tiksi',
#  'silver city',
#  'san ignacio',
#  'invercargill',
#  'yellowknife',
#  'vorgashor',
#  'georgetown',
#  'ilorin',
#  'port-aux-francais',
#  'edinburgh of the seven seas',
#  'caleta de carquin',
#  'waitangi',
#  'ciudad lazaro cardenas',
#  'enewetak',
#  'micheweni',
#  'oranjemund',
#  'zhezqazghan',
#  'longyearbyen',
#  'isafjordur',
#  'margaret river',
#  'devinuwara',
#  'tamanrasset',
#  'madison',
#  'talnakh',
#  'villa gesell',
#  'la passe',
#  'west island',
#  'cabedelo',
#  'port alfred',
#  'hermanus',
#  'novoishimskiy',
#  'lionel town',
#  'olonkinbyen',
#  'albany',
#  'hithadhoo',
#  'sabinanigo',
#  'ribeira grande',
#  'isangel',
#  'sandnessjoen',
#  'puerto gaitan',
#  'poronaysk',
#  'grytviken',
#  'okha',
#  'holualoa',
#  'astrakhan',
#  'hawaiian paradise park',
#  'fort st. john',
#  'port douglas',
#  'calca',
#  'ushuaia',
#  'bredasdorp',
#  'vingt cinq',
#  'cabo san lucas',
#  'ormara',
#  'punta arenas',
#  'bethel',
#  'alofi',
#  'chui',
#  'puerto ayora',
#  'bilibino',
#  'namibe',
#  'whitehorse',
#  'papatowai',
#  'puerto natales',
#  'buncrana',
#  'saldanha',
#  'afaahiti',
#  'atafu village',
#  'cadale',
#  'chibougamau',
#  'inongo',
#  'fuvahmulah',
#  'iqaluit',
#  'lysianka',
#  'dondo',
#  'progreso',
#  'isle of lewis',
#  'acapulco de juarez',
#  'kayangel',
#  'east london',
#  'guercif',
#  'sao jose da coroa grande',
#  'pullman',
#  'olinda',
#  'padang',
#  'taiohae',
#  'jackson',
#  'marka',
#  'santa cruz',
#  'mahibadhoo',
#  'attapeu',
#  'mahmutlar',
#  'bardai',
#  'jamestown',
#  'las palmas',
#  'port elizabeth',
#  'suva',
#  'onega',
#  'blackmans bay',
#  "sivers'k",
#  'new norfolk',
#  'hadibu',
#  'cacheu',
#  "port saint john's",
#  'vernon',
#  'vanimo',
#  "nar'yan-mar",
#  'lazaro cardenas',
#  'port moresby',
#  'daru',
#  'lebu',
#  'spring creek',
#  'guachochi',
#  'udachny',
#  'adamstown',
#  'sitka',
#  'contamana',
#  'yaren',
#  'freeport',
#  'manacapuru',
#  'arawa',
#  "la'ie",
#  'mutoko',
#  'nagqu',
#  'ribeira brava',
#  'ilebo',
#  'remire-montjoly',
#  'chiredzi',
#  'port mathurin',
#  'san isidro de curuguaty',
#  'hammerfest',
#  'iskateley',
#  'la mira',
#  'helensburgh',
#  'nueva gerona',
#  'tolanaro',
#  'omidiyeh',
#  'tazovsky',
#  'lihue',
#  'sainte-marie',
#  'likiep',
#  'sola',
#  'laojunmiao',
#  "'ohonua",
#  'vilyuchinsk',
#  'andergrove',
#  'narasannapeta',
#  'chonchi',
#  'puerto san carlos',
#  'kamaishi',
#  'mount isa',
#  'luanda',
#  'ilulissat',
#  'isiro',
#  'san patricio',
#  'tranovaho',
#  'muroto-misakicho',
#  'nemuro',
#  'kismayo',
#  'palmer',
#  'tiassale',
#  'gadzhiyevo',
#  'bikenibeu village',
#  'mareeba',
#  'miyako',
#  'awjilah',
#  'tawau',
#  'iranshahr',
#  'buala',
#  'nuuk',
#  'sokoni',
#  'saint-philippe',
#  'ghadamis',
#  'thompson',
#  'college',
#  'anadyr',
#  'krasnoufimsk',
#  'huarmey',
#  'aasiaat',
#  'qaqortoq',
#  'haiku-pauwela',
#  'san borja',
#  'itoman',
#  'mount gambier',
#  'pariaman',
#  'pisco',
#  "'ajab shir",
#  'arkalyk',
#  'guatire',
#  'warmbad',
#  'ola',
#  'kununurra',
#  'copiapo',
#  'vylkove',
#  'ust-nera',
#  'tura',
#  'thal',
#  'kone',
#  'nukunonu',
#  'fortuna',
#  'tasbuget',
#  'enoch',
#  'cable beach',
#  'gorontalo',
#  'kodiak',
#  'mugia',
#  'nigel',
#  'schweich',
#  'ancud',
#  'labrador city',
#  'sumbe',
#  'arar',
#  'ketchikan',
#  'benguela',
#  'ocean city',
#  'vega de alatorre',
#  'badger',
#  'buka',
#  'zangguy',
#  'lorengau',
#  'deols',
#  'lerwick',
#  'uturoa',
#  'walvis bay',
#  'hermiston',
#  'kavieng',
#  'rundu',
#  'port lincoln',
#  'el calafate',
#  'northam',
#  'wailua homesteads',
#  'viligili',
#  'fada',
#  'nyurba',
#  'el quebrachal',
#  'kupang',
#  'nambour',
#  'rasshevatskaya',
#  'aldinga beach',
#  'boonville',
#  'nizhniy odes',
#  'kailua-kona',
#  'kasserine',
#  'murray bridge',
#  'baiti',
#  'tabou',
#  'qiancheng',
#  'sinop',
#  'stanley',
#  'richards bay',
#  'puerto leguizamo',
#  'nicoya',
#  'hassi messaoud',
#  'nova sintra',
#  'xinyuan',
#  "st. john's",
#  'vallo della lucania',
#  'berezovyy',
#  'kapuskasing',
#  'kargasok',
#  'kathu',
#  'khandyga',
#  'hilo',
#  'namie',
#  "muzayri'",
#  'vila velha',
#  'jutai',
#  'quellon',
#  'yutan',
#  'dongola',
#  'meadow lake',
#  'eirunepe',
#  'flying fish cove',
#  'lompoc',
#  'adelanto',
#  'manicore',
#  'shuya',
#  'yuzhno-kurilsk',
#  'hamilton',
#  'gualeguay',
#  'severo-yeniseyskiy',
#  'auki',
#  'nishinoomote',
#  'brookings',
#  'lure',
#  'hami',
#  'bayanaul',
#  'las heras',
#  'weno',
#  'egilsstadir',
#  'joshimath',
#  'polyarnyy',
#  'sittwe',
#  'utrik',
#  'qamdo',
#  'dalyellup',
#  'port alberni',
#  'penzance',
#  'mossel bay',
#  'kalmunai',
#  'veraval',
#  'minas de marcona',
#  'petropavlovsk-kamchatsky',
#  'brisas barra de suchiate',
#  'puerto baquerizo moreno',
#  'medianeira',
#  'voronovytsya',
#  'anka',
#  'bornu yassu',
#  'bubaque',
#  'tome acu',
#  'kaya',
#  'sao vicente',
#  'laguna',
#  'am djarass',
#  'cockburn town',
#  'pionerskiy',
#  'karasburg',
#  'katsuren-haebaru',
#  'ujae',
#  'guerrero negro',
#  'palu',
#  'luau',
#  'barra de santo antonio',
#  'karkira',
#  'margate',
#  'tangalle',
#  'melfort',
#  'lensk',
#  'rikaze',
#  'enriquillo',
#  'wajir',
#  "ust'-ilimsk",
#  'corfu',
#  'saint-joseph',
#  'cassilandia',
#  'antonio enes',
#  'whitby',
#  'abepura',
#  'nyagan',
#  'avarua',
#  'san antonio de pale',
#  'peterhead',
#  'midrand',
#  'itamaraca',
#  'custodia',
#  'merizo village',
#  'carnarvon',
#  'ecoporanga',
#  'port jervis',
#  'vegueta',
#  'san jose village',
#  'mikhaylovskoye',
#  'vangaindrano',
#  'tionk essil',
#  'we',
#  'karratha',
#  'badiyah',
#  'codrington',
#  'lautoka',
#  'fort bragg',
#  'la grande',
#  'kratie',
#  'morehead city',
#  'saipan',
#  'lahat',
#  'dunedin',
#  'madimba',
#  'verkhnevilyuysk',
#  'victoria point',
#  'grand haven',
#  'juticalpa',
#  'kazaure',
#  'nova olinda do norte',
#  'sinabang',
#  'plastun',
#  'chernyshevskiy',
#  'colares',
#  'taguatinga',
#  'mar del plata',
#  'corowa',
#  'sevsk',
#  "arkhangel'sk",
#  'salekhard',
#  'alice springs',
#  'sampit',
#  'ahau',
#  'gargalianoi',
#  'el granada',
#  'kongolo',
#  'cabinda',
#  'nantucket',
#  'ofunato',
#  'susuman',
#  'luderitz',
#  'lobujya',
#  'dudinka',
#  'tsiombe',
#  'glace bay',
#  'klyuchi',
#  'fale old settlement',
#  'petukhovo',
#  'ailuk',
#  'brasileia',
#  'puerto aysen',
#  'siwa oasis',
#  'bandarbeyla',
#  'undurkhaan',
#  'senillosa',
#  'bojnurd',
#  'necochea',
#  'xilin hot',
#  'kill devil hills',
#  'azadshahr',
#  'madera',
#  'chunskiy',
#  'takamaka',
#  'riosucio',
#  'vershino-darasunskiy',
#  'kruisfontein',
#  'payson',
#  'istgah-e rah ahan-e garmsar',
#  'el entrego',
#  'toga village',
#  'naryn',
#  'rathdrum',
#  'arraial do cabo',
#  'balqash',
#  'rio grande',
#  'atar',
#  'thames',
#  'ghanzi',
#  'yagry',
#  'arucas',
#  'the pas',
#  'angaur state',
#  'warwick',
#  'saint-pierre',
#  'sokur',
#  'bouca',
#  'darnah',
#  'dunda',
#  'puerto deseado',
#  'stuttgart',
#  'partapur',
#  'kingston',
#  'ciudad del carmen',
#  'cavelossim',
#  'amasra',
#  'kosh-agach',
#  'yenisarbademli',
#  'nkove',
#  'chernyshevsk',
#  'ponta delgada',
#  'torbat-e jam',
#  'castillos',
#  'kuluncak',
#  'urangan',
#  'schuyler',
#  'geraldton',
#  'ardakan',
#  'presque isle',
#  'middleburg',
#  'inyonga',
#  'port macquarie',
#  'aykhal',
#  "bo'ka",
#  'kuta',
#  'khamis mushait',
#  'tralee',
#  'wuwei',
#  'callaway',
#  'korla',
#  "ust'-barguzin",
#  'hancheng',
#  'katsuura',
#  'vila franca do campo',
#  'ntossoni',
#  'pratt',
#  'sanming',
#  'narvik',
#  'ta`u',
#  'bam',
#  'chinde',
#  'cidreira',
#  'patnongon',
#  'piti village',
#  'akalkot',
#  'capao da canoa',
#  'xiongzhou',
#  'siqueira campos',
#  'wagar',
#  'aswan',
#  'santa terezinha',
#  'baneasa',
#  'beteza',
#  'yoro',
#  'qusmuryn',
#  'shingu',
#  'samamea',
#  'yeed',
#  'shiraz',
#  'sisimiut',
#  'santa ana',
#  "nuku'alofa",
#  'kavaratti',
#  'ulanhot',
#  'kutaisi',
#  'coruripe',
#  'mazeikiai',
#  'springbok',
#  'acarau',
#  'eyl',
#  'talcahuano',
#  'shalqar',
#  'ulladulla',
#  'gordonvale',
#  'petawawa',
#  'natal',
#  'tarko-sale',
#  'changping',
#  'thunder bay',
#  'yirol',
#  'santana',
#  'belyy yar',
#  'touros',
#  'emerald',
#  'freetown',
#  'wynyard',
#  'san-pedro',
#  'as sulayyil',
#  'santa barbara',
#  'watsa',
#  'taoudenni',
#  'arno',
#  'guaduas',
#  'vostochnyy',
#  'atbasar',
#  'faro',
#  'howrah',
#  'porto novo',
#  'villa luvianos',
#  'masuda',
#  'vadso',
#  'bathurst',
#  'hengchun',
#  'tonekabon',
#  'callao',
#  'dingcheng',
#  'mucumpiz',
#  'bac lieu',
#  'villanueva del arzobispo',
#  'naze',
#  'fort mcmurray',
#  'korsakov',
#  'ilaro',
#  'dera ghazi khan',
#  'klaksvik',
#  'saatli',
#  'kosong',
#  'trittau',
#  'gweru',
#  'galliano',
#  'samraong',
#  'vilhena',
#  'anaconda',
#  'gamba',
#  'minas de matahambre',
#  'hluti',
#  'wittenburg',
#  'witu',
#  'wiwili',
#  'chita',
#  "'ain el hadjel",
#  'tazacorte',
#  'recani',
#  'papao',
#  'la libertad',
#  'kirakira',
#  'saint-francois',
#  'turpan',
#  'lashio',
#  'debre tabor',
#  'pagar alam',
#  'griffith',
#  'leskovac',
#  'al jawf',
#  'levuka',
#  'taltal',
#  'lata',
#  'changzhi',
#  'piacabucu',
#  'new kingman-butler',
#  'ambikapur',
#  'isla mujeres',
#  'hun',
#  'labytnangi',
#  "kapa'a",
#  'vorkuta',
#  'vikhorevka',
#  'yigo village',
#  'constantia',
#  'kenai',
#  'blagoevgrad',
#  'guarapari',
#  'cruzeiro do sul',
#  'sterling',
#  'leland',
#  'ramtown',
#  'sarakhs',
#  'altai',
#  'severnoye']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=a4b719b11af797ca58c5942b718aabdc&q=san francisco

# %%
#Define base url with unique weather api key
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

#Create an empty list to get the weather data for each city
city_data = []

#Print to tell the user that data is being gathered
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters for record and set
record_count = 1
set_count = 1

#Loop through all the cities in city_data to get weather data
for i, city in enumerate(cities):
        
    #Group cities in groups of 50 each
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    #Create endpoint URL for each city
    city_url = f"{url}&q={city}"
    
    #Keep track the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    #Increment the record count by 1
    record_count += 1

    #Run an API request for each of the cities
    try:
        #Get the request and convert to json to get the raw data
        city_weather = requests.get(city_url).json()

        #Take the latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        #Append the previous values into the city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
#Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | silver city
# Processing Record 4 of Set 1 | san ignacio
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | vorgashor
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | ilorin
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | caleta de carquin
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | ciudad lazaro cardenas
# Processing Record 15 of Set 1 | enewetak
# Processing Record 16 of Set 1 | micheweni
# Processing Record 17 of Set 1 | oranjemund
# Processing Record 18 of Set 1 | zhezqazghan
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | isafjordur
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 23 of Set 1 | tamanrasset
# Processing Record 24 of Set 1 | madison
# Processing Record 25 of Set 1 | talnakh
# Processing Record 26 of Set 1 | villa gesell
# Processing Record 27 of Set 1 | la passe
# Processing Record 28 of Set 1 | west island
# Processing Record 29 of Set 1 | cabedelo
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | novoishimskiy
# Processing Record 33 of Set 1 | lionel town
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | sabinanigo
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | isangel
# Processing Record 40 of Set 1 | sandnessjoen
# Processing Record 41 of Set 1 | puerto gaitan
# Processing Record 42 of Set 1 | poronaysk
# Processing Record 43 of Set 1 | grytviken
# Processing Record 44 of Set 1 | okha
# Processing Record 45 of Set 1 | holualoa
# Processing Record 46 of Set 1 | astrakhan
# Processing Record 47 of Set 1 | hawaiian paradise park
# Processing Record 48 of Set 1 | fort st. john
# Processing Record 49 of Set 1 | port douglas
# Processing Record 50 of Set 1 | calca
# Processing Record 0 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | ormara
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | chui
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | bilibino
# Processing Record 11 of Set 2 | namibe
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | papatowai
# Processing Record 14 of Set 2 | puerto natales
# Processing Record 15 of Set 2 | buncrana
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | afaahiti
# Processing Record 18 of Set 2 | atafu village
# Processing Record 19 of Set 2 | cadale
# Processing Record 20 of Set 2 | chibougamau
# Processing Record 21 of Set 2 | inongo
# Processing Record 22 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | lysianka
# Processing Record 25 of Set 2 | dondo
# Processing Record 26 of Set 2 | progreso
# Processing Record 27 of Set 2 | isle of lewis
# City not found. Skipping...
# Processing Record 28 of Set 2 | acapulco de juarez
# Processing Record 29 of Set 2 | kayangel
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | guercif
# Processing Record 32 of Set 2 | sao jose da coroa grande
# Processing Record 33 of Set 2 | pullman
# Processing Record 34 of Set 2 | olinda
# Processing Record 35 of Set 2 | padang
# Processing Record 36 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 2 | jackson
# Processing Record 38 of Set 2 | marka
# Processing Record 39 of Set 2 | santa cruz
# Processing Record 40 of Set 2 | mahibadhoo
# Processing Record 41 of Set 2 | attapeu
# Processing Record 42 of Set 2 | mahmutlar
# Processing Record 43 of Set 2 | bardai
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | las palmas
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | suva
# Processing Record 48 of Set 2 | onega
# Processing Record 49 of Set 2 | blackmans bay
# Processing Record 0 of Set 3 | sivers'k
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | hadibu
# Processing Record 3 of Set 3 | cacheu
# Processing Record 4 of Set 3 | port saint john's
# Processing Record 5 of Set 3 | vernon
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | nar'yan-mar
# Processing Record 8 of Set 3 | lazaro cardenas
# Processing Record 9 of Set 3 | port moresby
# Processing Record 10 of Set 3 | daru
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | spring creek
# Processing Record 13 of Set 3 | guachochi
# City not found. Skipping...
# Processing Record 14 of Set 3 | udachny
# Processing Record 15 of Set 3 | adamstown
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | contamana
# Processing Record 18 of Set 3 | yaren
# Processing Record 19 of Set 3 | freeport
# Processing Record 20 of Set 3 | manacapuru
# Processing Record 21 of Set 3 | arawa
# Processing Record 22 of Set 3 | la'ie
# Processing Record 23 of Set 3 | mutoko
# Processing Record 24 of Set 3 | nagqu
# Processing Record 25 of Set 3 | ribeira brava
# Processing Record 26 of Set 3 | ilebo
# Processing Record 27 of Set 3 | remire-montjoly
# Processing Record 28 of Set 3 | chiredzi
# Processing Record 29 of Set 3 | port mathurin
# Processing Record 30 of Set 3 | san isidro de curuguaty
# Processing Record 31 of Set 3 | hammerfest
# Processing Record 32 of Set 3 | iskateley
# Processing Record 33 of Set 3 | la mira
# Processing Record 34 of Set 3 | helensburgh
# Processing Record 35 of Set 3 | nueva gerona
# Processing Record 36 of Set 3 | tolanaro
# Processing Record 37 of Set 3 | omidiyeh
# Processing Record 38 of Set 3 | tazovsky
# Processing Record 39 of Set 3 | lihue
# Processing Record 40 of Set 3 | sainte-marie
# Processing Record 41 of Set 3 | likiep
# Processing Record 42 of Set 3 | sola
# Processing Record 43 of Set 3 | laojunmiao
# Processing Record 44 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 3 | vilyuchinsk
# Processing Record 46 of Set 3 | andergrove
# Processing Record 47 of Set 3 | narasannapeta
# Processing Record 48 of Set 3 | chonchi
# Processing Record 49 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 4 | kamaishi
# Processing Record 1 of Set 4 | mount isa
# Processing Record 2 of Set 4 | luanda
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | isiro
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 4 | muroto-misakicho
# Processing Record 8 of Set 4 | nemuro
# Processing Record 9 of Set 4 | kismayo
# Processing Record 10 of Set 4 | palmer
# Processing Record 11 of Set 4 | tiassale
# Processing Record 12 of Set 4 | gadzhiyevo
# Processing Record 13 of Set 4 | bikenibeu village
# Processing Record 14 of Set 4 | mareeba

# %%
#Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#Show the count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
#Show the dataframe for the first five rows
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               yuni  13.4192  122.4833     29.59        72          52
# 1  port-aux-francais -49.3500   70.2167      5.49        92          97
# 2          adamstown -25.0660 -130.1015     17.80        91         100
# 3            santana  -0.0583  -51.1817     27.10        89           0
# 4              tiksi  71.6872  128.8694      1.92        71         100
#
#    Wind Speed Country        Date
# 0        1.79      PH  1694841475
# 1       15.61      TF  1694841475
# 2       15.88      PN  1694841476
# 3        4.12      BR  1694841476
# 4        7.79      RU  1694841476

# %%
#Export the city data dataframe to a csv file named cities.csv
city_data_df.to_csv("/Users/brendanguanminzhu/Desktop/python-api-challenge/output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 2
#       1 #Export the city data dataframe to a csv file named cities.csv
# ----> 2 city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
